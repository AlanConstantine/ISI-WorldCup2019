# %% [markdown]
# 成长能力分析

# %%
import pandas as pd
df_growth= pd.read_excel(r'.././Documents/赛题1数据集/上市信息财务信息-成长能力指标.xlsx')
df_growth.head(n=5)
A=['营业总收入(元)','毛利润(元)','归属净利润(元)','扣非净利润(元)']

# %%
#剔除单位
for arr in A:
    chinese = set(df_growth[arr].str.extract("([^0-9\.\-]+)", expand=False).dropna())
    print(arr, chinese)
# Out:
# 营业总收入(元) {'万亿', '亿', '万'}
# 毛利润(元) {'亿', '万'}
# 归属净利润(元) {'亿', '万'}
# 扣非净利润(元) {'亿', '万'}

# %%
for arr in A:
    df_growth.loc[(df_growth[arr].str.contains("万亿") == True), arr] = df_growth.loc[(
        df_growth[arr].str.contains("万亿") == True), arr].str.replace('万亿', '').astype(float)*1000000000000
    df_growth.loc[(df_growth[arr].str.contains("万") == True), arr] = df_growth.loc[(
        df_growth[arr].str.contains("万") == True), arr].str.replace('万', '').astype(float)*10000
    df_growth.loc[(df_growth[arr].str.contains("亿") == True), arr] = df_growth.loc[(
       df_growth[arr].str.contains("亿") == True), arr].str.replace('亿', '').astype(float)*100000000

# %%
for arr in A:
    chinese = set(df_growth[arr].str.extract("([^0-9\.\-]+)", expand=False).dropna())
    print(arr, chinese)
# Out:
# 营业总收入(元) set()
# 毛利润(元) set()
# 归属净利润(元) set()
# 扣非净利润(元) set()

# %%
# 转换为浮点数
for arr in A:

# %%
#增长比例去百分号处理
import numpy as np
B=['营业总收入同比增长(元)','归属净利润同比增长(元)','扣非净利润同比增长(元)','营业总收入滚动环比增长(元)','归属净利润滚动环比增长(元)','扣非净利润滚动环比增长(元)']
for arr in B:
      df_growth[arr] = df_growth[arr].replace('--%', np.nan)
df_growth.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28887 entries, 0 to 28886
# Data columns (total 13 columns):
# 企业编号              28887 non-null int64
# 标题                28887 non-null object
# 日期                28887 non-null object
# 营业总收入(元)          28877 non-null float64
# 毛利润(元)            28185 non-null float64
# 归属净利润(元)          28887 non-null float64
# 扣非净利润(元)          28406 non-null float64
# 营业总收入同比增长(元)      28229 non-null object
# 归属净利润同比增长(元)      24932 non-null object
# 扣非净利润同比增长(元)      22907 non-null object
# 营业总收入滚动环比增长(元)    27449 non-null object
# 归属净利润滚动环比增长(元)    25957 non-null object
# 扣非净利润滚动环比增长(元)    20908 non-null object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 2.9+ MB

# %%
df_growth.convert_objects(convert_numeric=True)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use DataFrame.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   """Entry point for launching an IPython kernel.
#        企业编号      标题          日期      营业总收入(元)        毛利润(元)      归属净利润(元)  \
# 0      1001  成长能力指标  2018-09-30  1.271000e+11           NaN  4.320000e+10
# 1      1001  成长能力指标  2018-06-30  8.230000e+10           NaN  2.860000e+10
# 2      1001  成长能力指标  2018-03-31  3.960000e+10           NaN  1.430000e+10
# 3      1001  成长能力指标  2017-12-31  1.686000e+11           NaN  5.430000e+10
# 4      1001  成长能力指标  2017-09-30  1.255000e+11           NaN  4.190000e+10
# 5      1001  成长能力指标  2017-06-30  8.400000e+10           NaN  2.820000e+10
# 28881  2.650000e+06      -22.89%       -3.68%        3.44%          2.39%
# 28882  3.120000e+06      -31.51%      -54.48%      -58.28%         -6.56%
# 28883  2.270000e+06      -35.12%      -60.16%      -63.86%        -12.45%
# 28884  1.450000e+06      -30.53%      -49.08%      -54.19%         -7.95%
# 28885  2.560000e+06       -3.20%      -67.64%      -74.55%        -11.45%
# 28886  7.470000e+06       13.99%       10.42%        8.07%          1.20%
#
#       归属净利润滚动环比增长(元) 扣非净利润滚动环比增长(元)
# 0              1.67%          1.67%
# 1              1.04%          1.02%
# 2             -0.29%          0.48%
# 3             -0.09%          1.44%
# 4             -0.34%          0.34%
# 5              1.59%          2.10%
# 6              1.02%          0.63%
# 7             -1.89%         -2.24%
# 8              1.22%          1.09%
# 9            -11.87%        -13.78%
# 10            -6.34%         -8.09%
# 11             1.57%          3.28%
# 12             5.43%          0.77%
# 13             2.58%          4.44%
# 14             1.45%          3.85%
# 15             4.33%          2.84%
# 16             0.74%          2.16%
# 17             4.05%          3.70%
# 18            39.75%         37.17%
# 19            37.44%         31.22%
# 20            29.49%         24.63%
# 21            87.56%        129.49%
# 22           -18.45%        -27.58%
# 23           -21.83%        -24.66%
# 24           -23.30%        -21.94%
# 25            -8.67%         14.21%
# 26           -27.60%        -21.72%
# 27             0.51%          4.16%
# 28             9.72%         11.08%
# 29             6.78%          7.19%
# ...              ...            ...
# 28857         13.23%         12.91%
# 28858         -6.61%          6.54%
# 28859         -5.83%         -6.39%
# 28860        -85.27%       -132.10%
# 28861        -12.50%        -21.83%
# 28862          1.27%          0.78%
# 28863         -7.53%        -30.42%
# 28864         25.42%          7.92%
# 28865         -6.75%         -7.43%
# 28866          2.88%          2.22%
# 28867         96.71%         98.95%
# 28868        144.26%        166.48%
# 28869        -50.51%        -67.60%
# 28870          9.94%         18.48%
# 28871         -6.47%        -15.65%
# 28872        -28.90%          1.16%
# 28873         11.94%         22.32%
# 28874         -7.54%        -14.72%
# 28875         -1.51%         -4.46%
# 28876         -7.39%         -0.48%
# 28877         -3.66%         -5.96%
# 28878         -9.25%         -2.49%
# 28879        -20.73%        -27.61%
# 28880          1.92%         13.65%
# 28881            NaN            NaN
# 28882            NaN            NaN
# 28883       -115.64%       -271.05%
# 28884        -45.24%        -67.09%
# 28885        -69.69%        -75.88%
# 28886          3.11%          1.74%
#
# [28887 rows x 13 columns]

# %%
for arr in B:
      df_growth.loc[(df_growth[arr].str.contains("%") == True), arr] = df_growth.loc[(
        df_growth[arr].str.contains("%") == True), arr].str.rstrip('%').astype(float)/100
df_growth.info()
df_growth.corr()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-02ea64eb8fb6> in <module>
#       1 for arr in B:
#       2       df_growth.loc[(df_growth[arr].str.contains("%") == True), arr] = df_growth.loc[(
# ----> 3         df_growth[arr].str.contains("%") == True), arr].str.rstrip('%').astype(float)/100
#       4 df_growth.info()
#       5 df_growth.corr()
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5051         if (name in self._internal_names_set or name in self._metadata or
#    5052                 name in self._accessors):
# -> 5053             return object.__getattribute__(self, name)
#    5054         else:
#    5055             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     169             # we're accessing the attribute of the class, i.e., Dataset.geo
#     170             return self._accessor
# --> 171         accessor_obj = self._accessor(obj)
#     172         # Replace the property with the accessor object. Inspired by:
#     173         # http://www.pydanny.com/cached-property.html
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/strings.py in __init__(self, data)
#    1794
#    1795     def __init__(self, data):
# -> 1796         self._validate(data)
#    1797         self._is_categorical = is_categorical_dtype(data)
#    1798
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/strings.py in _validate(data)
#    1816             # (instead of test for object dtype), but that isn't practical for
#    1817             # performance reasons until we have a str dtype (GH 9343)
# -> 1818             raise AttributeError("Can only use .str accessor with string "
#    1819                                  "values, which use np.object_ dtype in "
#    1820                                  "pandas")
#
# AttributeError: Can only use .str accessor with string values, which use np.object_ dtype in pandas

# %%
# 归属净利润(元)和扣非净利润(元)的回归分析
# data_1= {'归属':df['归属净利润(元)'],'扣非': df['扣非净利润(元)'],}
# data_1= pd.DataFrame(data_1) 
# data_1.info()
# data_11=data_1.dropna()
# data_11.info()
# data_11.corr()
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28887 entries, 0 to 28886
# Data columns (total 2 columns):
# 归属    28887 non-null float64
# 扣非    28406 non-null float64
# dtypes: float64(2)
# memory usage: 451.4 KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28406 entries, 0 to 28886
# Data columns (total 2 columns):
# 归属    28406 non-null float64
# 扣非    28406 non-null float64
# dtypes: float64(2)
# memory usage: 665.8 KB
# Out[24]:
# 归属	扣非
# 归属	1.000000	0.998745
# 扣非	0.998745	1.000000

# %%
# from sklearn.model_selection import train_test_split
# from sklearn.linear_model import LinearRegression
# X_train,X_test,Y_train,Y_test = train_test_split(data_11.iloc[:,:1],data_11['扣非'],train_size=.80)
# model = LinearRegression()
# model.fit(X_train,Y_train)
# a3 = model.intercept_ 
# b3 = model.coef_
# print("最佳拟合线:截距",a3,",回归系数：",b3)
# score = model.score(X_test,Y_test)
# print("回归得分:",score)
# len(data_11.loc[(data_11['归属']==data_11['扣非'])])
#归属净利润(元) 和扣非净利润(元) 高度相关
# 最佳拟合线:截距 -42306152.263234854 ,回归系数： [0.98677438]
# 回归得分: 0.9917088881664324

# %%
#利润表中有些数据和营业总收入以及毛利润相关，因此进行检验
# import pandas as pd
# df_1= pd.read_excel('/Users/zengxiaoyu/Documents/赛题1数据集/上市信息财务信息-利润表(清楚单位).xlsx')
# import  numpy as np
# df_11=df_1["营业收入(元)"].groupby([df_1["企业编号"]]).mean()
# df_11.index[np.where(np.isnan(df_11))[0]] 
# #营业收入只有编号1932全部缺失

# %%
# data_3= {'a':df_11,'b': df3,}
# data_3= pd.DataFrame(data_3) 
# data_3.info()
# data_31=data_3.dropna()
# data_31.info()
# X_train,X_test,Y_train,Y_test = train_test_split(data_31.iloc[:,:1],data_31["b"],train_size=.80)
# model = LinearRegression()
# model.fit(X_train,Y_train)
# a3 = model.intercept_ 
# b3 = model.coef_
# print("最佳拟合线:截距",a3,",回归系数：",b3)
# score = model.score(X_test,Y_test)
# print("回归得分:",score)
# data_31.corr()
# 营业收入和营业总收入较强线性相关性。最佳拟合线:截距 63803182.45782375 ,回归系数： [0.96381012] 回归得分: 0.9992416496440518

# %%
# data_2= {'a':df3,'b': df2,}
# data_2= pd.DataFrame(data_2) 
# data_2.info()
# data_21=data_2.dropna()
# data_21.info()
# X_train,X_test,Y_train,Y_test = train_test_split(data_21.iloc[:,:1],data_21["b"],train_size=.80)
# model = LinearRegression()
# model.fit(X_train,Y_train)
# a3 = model.intercept_ 
# b3 = model.coef_
# print("最佳拟合线:截距",a3,",回归系数：",b3)
# score = model.score(X_test,Y_test)
# print("回归得分:",score)
# data_21.corr()

#毛利润=营业收入-营业成本 回归得分 0.74 毛利润=0.1*营业总收入 回归得分0.92

# %%
# 对数值型指标和评分的相关性分析
agg_func = {
   '营业总收入(元)': ['mean', 'max', 'min','std'],
    '毛利润(元)': ['mean', 'max', 'min','std'],
    '归属净利润(元)': ['mean', 'max', 'min','std'],
    '扣非净利润(元)': ['mean', 'max', 'min','std'],
}
df_growth_new = df_growth.groupby(['企业编号']).agg(agg_func)
df_growth_new.columns = ['_'.join(col) for col in df_growth_new.columns.values]
df_growth_new.columns = [
    '营业总收入(元)_mean', '营业总收入(元)_max', '营业总收入(元)_min', '营业总收入(元)_std','毛利润(元)_mean', '毛利润(元)_max', '毛利润(元)_min', '毛利润(元)_std',
     '归属净利润(元)_mean', '归属净利润(元)_max', '归属净利润(元)_min', '归属净利润(元)_std', '扣非净利润(元)_mean', '扣非净利润(元)_max', '扣非净利润(元)_min', '扣非净利润(元)_std']
df_growth_new['企业编号'] = df_growth_new.index
df_growth_new.head(n=3)
# Out:
#       营业总收入(元)_mean  营业总收入(元)_max  营业总收入(元)_min  营业总收入(元)_std   毛利润(元)_mean  \
# 企业编号
# 1001   1.057444e+11  1.686000e+11  3.960000e+10  4.664352e+10           NaN
# 1002   4.267778e+09  6.760000e+09  1.580000e+09  1.864328e+09  1.550778e+09
# 1003   9.697778e+09  1.830000e+10  2.460000e+09  5.360030e+09  1.057222e+09
#
#         毛利润(元)_max   毛利润(元)_min    毛利润(元)_std  归属净利润(元)_mean  归属净利润(元)_max  \
# 企业编号
# 1001           NaN          NaN           NaN   3.542222e+10  5.430000e+10
# 1002  2.650000e+09  599000000.0  7.062506e+08   9.415556e+08  1.600000e+09
# 1003  1.950000e+09  350000000.0  5.715172e+08   2.001456e+08  4.140000e+08
#
#       归属净利润(元)_min  归属净利润(元)_std  扣非净利润(元)_mean  扣非净利润(元)_max  扣非净利润(元)_min  \
# 企业编号
# 1001  1.430000e+10  1.492387e+10   3.488889e+10  5.400000e+10  1.400000e+10
# 1002  4.080000e+08  4.080506e+08   9.332222e+08  1.560000e+09  3.810000e+08
# 1003  7.031000e+07  1.051655e+08   1.817589e+08  3.510000e+08  6.583000e+07
#
#       扣非净利润(元)_std  企业编号
# 企业编号
# 1001  1.471975e+10  1001
# 1002  4.058906e+08  1002
# 1003  8.912277e+07  1003

# %%
df_growth_xiangguanfenxi=df_growth_new.copy()
df_growth_xiangguanfenxi.info()
score= pd.read_excel(r'.././Documents/赛题1数据集/企业评分.xlsx')
score.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2986 entries, 1001 to 4000
# Data columns (total 17 columns):
# 营业总收入(元)_mean    2986 non-null float64
# 营业总收入(元)_max     2986 non-null float64
# 营业总收入(元)_min     2986 non-null float64
# 营业总收入(元)_std     2986 non-null float64
# 毛利润(元)_mean      2917 non-null float64
# 毛利润(元)_max       2917 non-null float64
# 毛利润(元)_min       2917 non-null float64
# 毛利润(元)_std       2917 non-null float64
# 归属净利润(元)_mean    2986 non-null float64
# 归属净利润(元)_max     2986 non-null float64
# 归属净利润(元)_min     2986 non-null float64
# 归属净利润(元)_std     2986 non-null float64
# 扣非净利润(元)_mean    2986 non-null float64
# 扣非净利润(元)_max     2986 non-null float64
# 扣非净利润(元)_min     2986 non-null float64
# 扣非净利润(元)_std     2986 non-null float64
# 企业编号             2986 non-null int64
# dtypes: float64(16), int64(1)
# memory usage: 419.9 KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2995 entries, 0 to 2994
# Data columns (total 2 columns):
# 企业编号     2995 non-null int64
# 企业总评分    2995 non-null float64
# dtypes: float64(1), int64(1)
# memory usage: 46.9 KB

# %%
df_growth_xiangguanfenxicor=df_growth_xiangguanfenxi.merge(score, how='inner', left_index=True,right_on="企业编号")
df_growth_xiangguanfenxicor.info()
columns = ['企业总评分',
         '营业总收入(元)_mean', '营业总收入(元)_max', '营业总收入(元)_min', '营业总收入(元)_std','毛利润(元)_mean', '毛利润(元)_max', '毛利润(元)_min', '毛利润(元)_std',
     '归属净利润(元)_mean', '归属净利润(元)_max', '归属净利润(元)_min', '归属净利润(元)_std', '扣非净利润(元)_mean', '扣非净利润(元)_max', '扣非净利润(元)_min', '扣非净利润(元)_std']
df_growth_xiangguanfenxicor = pd.DataFrame(df_growth_xiangguanfenxicor, columns=columns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2928 entries, 1 to 2994
# Data columns (total 20 columns):
# 企业编号             2928 non-null int64
# 营业总收入(元)_mean    2928 non-null float64
# 营业总收入(元)_max     2928 non-null float64
# 营业总收入(元)_min     2928 non-null float64
# 营业总收入(元)_std     2928 non-null float64
# 毛利润(元)_mean      2928 non-null float64
# 毛利润(元)_max       2928 non-null float64
# 毛利润(元)_min       2928 non-null float64
# 毛利润(元)_std       2928 non-null float64
# 归属净利润(元)_mean    2928 non-null float64
# 归属净利润(元)_max     2928 non-null float64
# 归属净利润(元)_min     2928 non-null float64
# 归属净利润(元)_std     2928 non-null float64
# 扣非净利润(元)_mean    2928 non-null float64
# 扣非净利润(元)_max     2928 non-null float64
# 扣非净利润(元)_min     2928 non-null float64
# 扣非净利润(元)_std     2928 non-null float64
# 企业编号_x           2928 non-null int64
# 企业编号_y           2928 non-null int64
# 企业总评分            2928 non-null float64
# dtypes: float64(17), int64(3)
# memory usage: 480.4 KB

# %%
df_growth_xiangguanfenxicor=df_growth_xiangguanfenxicor.dropna()
df_growth_xiangguanfenxicor.info()
df_growth_xiangguanfenxicor.corr()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2928 entries, 1 to 2994
# Data columns (total 17 columns):
# 企业总评分            2928 non-null float64
# 营业总收入(元)_mean    2928 non-null float64
# 营业总收入(元)_max     2928 non-null float64
# 营业总收入(元)_min     2928 non-null float64
# 营业总收入(元)_std     2928 non-null float64
# 毛利润(元)_mean      2928 non-null float64
# 毛利润(元)_max       2928 non-null float64
# 毛利润(元)_min       2928 non-null float64
# 毛利润(元)_std       2928 non-null float64
# 归属净利润(元)_mean    2928 non-null float64
# 归属净利润(元)_max     2928 non-null float64
# 归属净利润(元)_min     2928 non-null float64
# 归属净利润(元)_std     2928 non-null float64
# 扣非净利润(元)_mean    2928 non-null float64
# 扣非净利润(元)_max     2928 non-null float64
# 扣非净利润(元)_min     2928 non-null float64
# 扣非净利润(元)_std     2928 non-null float64
# dtypes: float64(17)
# memory usage: 411.8 KB
#                   企业总评分  营业总收入(元)_mean  营业总收入(元)_max  营业总收入(元)_min  \
# 企业总评分          1.000000       0.066883      0.066449      0.065937
# 营业总收入(元)_mean  0.066883       1.000000      0.993503      0.988419
# 营业总收入(元)_max   0.066449       0.993503      1.000000      0.967025
# 营业总收入(元)_min   0.065937       0.988419      0.967025      1.000000
# 营业总收入(元)_std   0.065853       0.980113      0.995969      0.941066
# 毛利润(元)_mean    0.088486       0.939876      0.928186      0.937835
# 毛利润(元)_max     0.090531       0.934336      0.929509      0.923669
# 毛利润(元)_min     0.085669       0.920310      0.900643      0.933375
# 毛利润(元)_std     0.088476       0.928175      0.928299      0.911103
# 归属净利润(元)_mean  0.085080       0.632439      0.664214      0.574660
# 归属净利润(元)_max   0.077550       0.525818      0.571023      0.456692
# 归属净利润(元)_min   0.030436       0.434795      0.422958      0.438926
# 归属净利润(元)_std   0.069403       0.414408      0.466010      0.339332
# 扣非净利润(元)_mean  0.084246       0.618529      0.651176      0.560566
# 扣非净利润(元)_max   0.075949       0.531145      0.575222      0.464762
# 扣非净利润(元)_min   0.020537       0.296096      0.284838      0.297258
# 扣非净利润(元)_std   0.068824       0.423440      0.474109      0.350852
#
#                营业总收入(元)_std  毛利润(元)_mean  毛利润(元)_max  毛利润(元)_min  毛利润(元)_std  \
# 企业总评分              0.065853     0.088486    0.090531    0.085669    0.088476
# 营业总收入(元)_mean      0.980113     0.939876    0.934336    0.920310    0.928175
# 营业总收入(元)_max       0.995969     0.928186    0.929509    0.900643    0.928299
# 营业总收入(元)_min       0.941066     0.937835    0.923669    0.933375    0.911103
# 营业总收入(元)_std       1.000000     0.910177    0.916444    0.875407    0.919275
# 毛利润(元)_mean        0.910177     1.000000    0.995825    0.982907    0.987809
# 毛利润(元)_max         0.916444     0.995825    1.000000    0.967686    0.996744
# 毛利润(元)_min         0.875407     0.982907    0.967686    1.000000    0.947462
# 毛利润(元)_std         0.919275     0.987809    0.996744    0.947462    1.000000
# 归属净利润(元)_mean      0.687675     0.652162    0.658751    0.640031    0.650191
# 归属净利润(元)_max       0.604462     0.520466    0.532120    0.498924    0.531870
