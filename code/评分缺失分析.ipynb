# %%
import pandas as pd
df= pd.read_excel(r'.././Documents/赛题1数据集/工商基本信息表.xlsx')
df1=pd.read_excel(r'.././Documents/赛题1数据集/企业评分.xlsx')
df.info()
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 19 columns):
# 企业编号          3000 non-null int64
# 注册资本（万元）      3000 non-null float64
# 注册资本币种(正则)    3000 non-null object
# 成立日期          3000 non-null object
# 经营状态          3000 non-null object
# 行业大类（代码）      2999 non-null object
# 行业小类（代码）      2999 non-null object
# 类型            3000 non-null object
# 省份代码          3000 non-null int64
# 城市代码          3000 non-null int64
# 地区代码          3000 non-null int64
# 是否上市          3000 non-null object
# 经营期限自         2987 non-null object
# 经营期限至         521 non-null object
# 登记机关区域代码      2992 non-null float64
# 发照日期          2979 non-null object
# 员工人数          2986 non-null float64
# 注销原因          227 non-null object
# 注销时间          1 non-null object
# dtypes: float64(3), int64(4), object(12)
# memory usage: 445.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2995 entries, 0 to 2994
# Data columns (total 2 columns):
# ...

# %%
df2=pd.merge(df,df1,how='left')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3039 entries, 0 to 3038
# Data columns (total 20 columns):
# 企业编号          3039 non-null int64
# 注册资本（万元）      3039 non-null float64
# 注册资本币种(正则)    3039 non-null object
# 成立日期          3039 non-null object
# 经营状态          3039 non-null object
# 行业大类（代码）      3038 non-null object
# 行业小类（代码）      3038 non-null object
# 类型            3039 non-null object
# 省份代码          3039 non-null int64
# 城市代码          3039 non-null int64
# 地区代码          3039 non-null int64
# 是否上市          3039 non-null object
# 经营期限自         3026 non-null object
# 经营期限至         530 non-null object
# 登记机关区域代码      3031 non-null float64
# 发照日期          3018 non-null object
# 员工人数          3025 non-null float64
# 注销原因          229 non-null object
# 注销时间          1 non-null object
# 企业总评分         2995 non-null float64
# dtypes: float64(4), int64(4), object(12)
# memory usage: 498.6+ KB

# %%
print(df2[df2.duplicated()])
# Out:
#       企业编号    注册资本（万元） 注册资本币种(正则)        成立日期          经营状态 行业大类（代码） 行业小类（代码）  \
# 121   1121   30.555360          -  2000-09-30  存续（在营、开业、在册）        C       39
# 157   1156   20.233012          -  1999-12-12  存续（在营、开业、在册）        L       72
# 242   1240   45.933395        人民币  1991-06-22  存续（在营、开业、在册）        F       52
# 279   1276   29.492651        人民币  1998-01-20  存续（在营、开业、在册）        F       52
# 357   1353   63.956113        人民币  1995-08-21            存续        E       47
# 432   1427   16.999078        人民币  1993-11-08      在营（开业）企业        C       30
# 468   1462   10.000000        人民币  1997-02-04  存续（在营、开业、在册）        C       15
# 555   1548   41.376088        人民币  2001-12-29            存续        E       49
# 606   1598  124.329064          -  1995-02-09  存续（在营、开业、在册）        C       14
# 655   1646   50.240000        人民币  1996-08-01            存续        L       72
# 662   1652   13.440000        人民币  2003-02-14  存续（在营、开业、在册）        D       45
# ...

# %%
dup=df2[df2.duplicated()].count()
dup
#完整的=2995-39=2956
#缺失的=3000-2956=44
# Out:
# 企业编号          39
# 注册资本（万元）      39
# 注册资本币种(正则)    39
# 成立日期          39
# 经营状态          39
# 行业大类（代码）      39
# 行业小类（代码）      39
# 类型            39
# 省份代码          39
# 城市代码          39
# 地区代码          39
# 是否上市          39
# 经营期限自         39
# 经营期限至          9
# 登记机关区域代码      39
# 发照日期          39
# 员工人数          39
# 注销原因           2
# 注销时间           0
# 企业总评分         39
# dtype: int64
