# %% [markdown]
# #每股指标

# %%
import pandas as pd
df_meiguzhibiao= pd.read_excel(r'.././Documents/赛题1数据集/上市公司财务信息-每股指标.xlsx')
df_meiguzhibiao.info()
len(df_meiguzhibiao.loc[df_meiguzhibiao['扣非每股收益(元)']==df_meiguzhibiao['稀释每股收益(元)']])
#j
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28887 entries, 0 to 28886
# Data columns (total 10 columns):
# 企业编号          28887 non-null int64
# 标题            28887 non-null object
# 日期            28887 non-null object
# 基本每股收益(元)     28887 non-null object
# 扣非每股收益(元)     28887 non-null object
# 稀释每股收益(元)     26099 non-null object
# 每股净资产(元)      26099 non-null object
# 每股公积金(元)      26099 non-null object
# 每股未分配利润(元)    26099 non-null object
# 每股经营现金流(元)    26099 non-null object
# dtypes: int64(1), object(9)
# memory usage: 2.2+ MB
# 26099

# %%
A=['基本每股收益(元)','扣非每股收益(元)','稀释每股收益(元)','每股净资产(元)','每股公积金(元)','每股未分配利润(元)','每股经营现金流(元)']
for arr in A:
    df_meiguzhibiao[arr]=pd.to_numeric(df_meiguzhibiao[arr],errors='coerce')

# %%
df_meiguzhibiao.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28887 entries, 0 to 28886
# Data columns (total 10 columns):
# 企业编号          28887 non-null int64
# 标题            28887 non-null object
# 日期            28887 non-null object
# 基本每股收益(元)     28824 non-null float64
# 扣非每股收益(元)     28073 non-null float64
# 稀释每股收益(元)     25462 non-null float64
# 每股净资产(元)      25597 non-null float64
# 每股公积金(元)      25456 non-null float64
# 每股未分配利润(元)    25586 non-null float64
# 每股经营现金流(元)    25613 non-null float64
# dtypes: float64(7), int64(1), object(2)
# memory usage: 2.2+ MB

# %%
# 相互之间的相关性检验，基本每股收益和扣非每股收益和稀释每股收益高度相关，删除稀释每股收益

# %%
# #特征统计特征值
agg_func = {
    '基本每股收益(元)': ['mean', 'max', 'min','std'],
    '扣非每股收益(元)': ['mean', 'max', 'min','std'],
    '每股净资产(元)': ['mean', 'max', 'min','std'],
    '每股公积金(元)': ['mean', 'max', 'min','std'],
    '每股未分配利润(元)':['mean', 'max', 'min','std'],
    '每股经营现金流(元)':['mean','max','min','std'],
}
df_meiguzhibiao_new = df_meiguzhibiao.groupby(['企业编号']).agg(agg_func)
df_meiguzhibiao_new.columns = ['_'.join(col) for col in df_meiguzhibiao_new.columns.values]
df_meiguzhibiao_new.columns = [
    '基本每股收益_mean', '基本每股收益_max', '基本每股收益_min', '基本每股收益_std','扣非每股收益_mean', '扣非每股收益_max', '扣非每股收益_min', '扣非每股收益_std',
     '每股净资产_mean', '每股净资产_max', '每股净资产_min', '每股净资产_std', '每股公积金_mean', '每股公积金_max', '每股公积金_min', '每股公积金_std',
     '每股未分配利润_mean', '每股未分配利润_max', '每股未分配利润_min', '每股未分配利润_std', '每股经营现金流_mean', '每股经营现金流_max', '每股经营现金流_min', '每股经营现金流_std']
df_meiguzhibiao_new['企业编号'] = df_meiguzhibiao_new.index
df_meiguzhibiao_new.head(n=3)
# Out:
#       基本每股收益_mean  基本每股收益_max  基本每股收益_min  基本每股收益_std  扣非每股收益_mean  \
# 企业编号
# 1001     1.335222      2.4040      0.4600    0.637924     1.335222
# 1002     0.601111      1.2100      0.2100    0.322895     0.568889
# 1003     0.100100      0.2069      0.0352    0.052533     0.100100
#
#       扣非每股收益_max  扣非每股收益_min  扣非每股收益_std  每股净资产_mean  每股净资产_max  ...  \
# 企业编号                                                             ...
# 1001      2.4040      0.4600    0.637924   14.280667    16.2000  ...
# 1002      0.9800      0.2100    0.280911    8.230900     9.6736  ...
# 1003      0.2069      0.0352    0.052533    3.345133     3.5143  ...
#
#       每股公积金_std  每股未分配利润_mean  每股未分配利润_max  每股未分配利润_min  每股未分配利润_std  \
# 企业编号
# 1001   0.382363      4.114956       5.1276       3.3708     0.507274
# 1002   0.438704      3.494911       4.8382       2.4992     0.899151
# 1003   0.000900      1.655433       1.8095       1.5825     0.079008
#
#       每股经营现金流_mean  每股经营现金流_max  每股经营现金流_min  每股经营现金流_std  企业编号
# 企业编号
# 1001     -6.708933      -1.6600     -12.3358     3.473729  1001
# 1002      0.950211       1.7009       0.3076     0.434158  1002
# 1003     -0.252300       0.3714      -0.5147     0.255316  1003
#
# [3 rows x 25 columns]

# %%
df_meiguzhibiao_xiangguanfenxi=df_meiguzhibiao_new.copy()
df_meiguzhibiao_xiangguanfenxi.info()
score= pd.read_excel(r'.././Documents/赛题1数据集/企业评分.xlsx')
score.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2986 entries, 1001 to 4000
# Data columns (total 25 columns):
# 基本每股收益_mean     2986 non-null float64
# 基本每股收益_max      2986 non-null float64
# 基本每股收益_min      2986 non-null float64
# 基本每股收益_std      2986 non-null float64
# 扣非每股收益_mean     2953 non-null float64
# 扣非每股收益_max      2953 non-null float64
# 扣非每股收益_min      2953 non-null float64
# 扣非每股收益_std      2943 non-null float64
# 每股净资产_mean      2700 non-null float64
# 每股净资产_max       2700 non-null float64
# 每股净资产_min       2700 non-null float64
# 每股净资产_std       2700 non-null float64
# 每股公积金_mean      2695 non-null float64
# 每股公积金_max       2695 non-null float64
# 每股公积金_min       2695 non-null float64
# 每股公积金_std       2695 non-null float64
# 每股未分配利润_mean    2700 non-null float64
# 每股未分配利润_max     2700 non-null float64
# 每股未分配利润_min     2700 non-null float64
# 每股未分配利润_std     2700 non-null float64
# 每股经营现金流_mean    2700 non-null float64
# 每股经营现金流_max     2700 non-null float64
# 每股经营现金流_min     2700 non-null float64
# 每股经营现金流_std     2700 non-null float64
# 企业编号            2986 non-null int64
# dtypes: float64(24), int64(1)
# memory usage: 606.5 KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2995 entries, 0 to 2994
# Data columns (total 2 columns):
# 企业编号     2995 non-null int64
# 企业总评分    2995 non-null float64
# dtypes: float64(1), int64(1)
# memory usage: 46.9 KB

# %%
df_meiguzhibiao_xiangguanfenxi["评分"]= score["企业总评分"]
columns = ['评分',
    '基本每股收益_mean', '基本每股收益_max', '基本每股收益_min', '基本每股收益_std','扣非每股收益_mean', '扣非每股收益_max', '扣非每股收益_min', '扣非每股收益_std',
     '每股净资产_mean', '每股净资产_max', '每股净资产_min', '每股净资产_std', '每股公积金_mean', '每股公积金_max', '每股公积金_min', '每股公积金_std',
     '每股未分配利润_mean', '每股未分配利润_max', '每股未分配利润_min', '每股未分配利润_std', '每股经营现金流_mean', '每股经营现金流_max', '每股经营现金流_min', '每股经营现金流_std']
df_meiguzhibiao_xiangguanfenxi = pd.DataFrame(df_meiguzhibiao_xiangguanfenxi, columns = columns)
df_meiguzhibiao_xiangguanfenxi.info()

df_meiguzhibiao_xiangguanfenxi.corr()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2986 entries, 1001 to 4000
# Data columns (total 25 columns):
# 评分              1983 non-null float64
# 基本每股收益_mean     2986 non-null float64
# 基本每股收益_max      2986 non-null float64
# 基本每股收益_min      2986 non-null float64
# 基本每股收益_std      2986 non-null float64
# 扣非每股收益_mean     2953 non-null float64
# 扣非每股收益_max      2953 non-null float64
# 扣非每股收益_min      2953 non-null float64
# 扣非每股收益_std      2943 non-null float64
# 每股净资产_mean      2700 non-null float64
# 每股净资产_max       2700 non-null float64
# 每股净资产_min       2700 non-null float64
# 每股净资产_std       2700 non-null float64
# 每股公积金_mean      2695 non-null float64
# 每股公积金_max       2695 non-null float64
# 每股公积金_min       2695 non-null float64
# 每股公积金_std       2695 non-null float64
# 每股未分配利润_mean    2700 non-null float64
# 每股未分配利润_max     2700 non-null float64
# 每股未分配利润_min     2700 non-null float64
# 每股未分配利润_std     2700 non-null float64
# 每股经营现金流_mean    2700 non-null float64
# 每股经营现金流_max     2700 non-null float64
# 每股经营现金流_min     2700 non-null float64
# 每股经营现金流_std     2700 non-null float64
# dtypes: float64(25)
# memory usage: 606.5 KB
#                     评分  基本每股收益_mean  基本每股收益_max  基本每股收益_min  基本每股收益_std  \
# 评分            1.000000     0.035042    0.023409    0.045495   -0.000200
# 基本每股收益_mean   0.035042     1.000000    0.936138    0.595675    0.675935
# 基本每股收益_max    0.023409     0.936138    1.000000    0.394668    0.850456
# 基本每股收益_min    0.045495     0.595675    0.394668    1.000000   -0.129408
# 基本每股收益_std   -0.000200     0.675935    0.850456   -0.129408    1.000000
# 扣非每股收益_mean   0.038397     0.981994    0.913376    0.590140    0.648016
# 扣非每股收益_max    0.020195     0.910090    0.965170    0.381743    0.815467
# 扣非每股收益_min    0.058769     0.594699    0.394508    0.984975   -0.127749
# 扣非每股收益_std   -0.010169     0.649912    0.825902   -0.164024    0.985854
# 每股净资产_mean    0.022814     0.772025    0.747937    0.375918    0.603717
# 每股净资产_max     0.036417     0.773306    0.790018    0.327570    0.666669
# 每股净资产_min     0.006256     0.676899    0.612345    0.426222    0.441609
# 每股净资产_std     0.058573     0.490697    0.592064    0.049032    0.590399
# 每股公积金_mean    0.063814     0.261543    0.299605    0.030250    0.305075
# 每股公积金_max     0.072524     0.296078    0.359640    0.053403    0.346398
# 每股公积金_min     0.030753     0.088699    0.103579   -0.042472    0.141394
# 每股公积金_std     0.072154     0.306551    0.371164    0.102115    0.326207
# 每股未分配利润_mean  0.002510     0.845655    0.785180    0.491855    0.581966
# 每股未分配利润_max   0.005038     0.860864    0.842194    0.412755    0.680620
# 每股未分配利润_min   0.000461     0.756312    0.650925    0.587867    0.396606
# 每股未分配利润_std   0.007901     0.523186    0.653390   -0.111698    0.744380
# 每股经营现金流_mean -0.023714     0.345514    0.319633    0.166444    0.236677
# 每股经营现金流_max  -0.010396     0.381290    0.387673    0.137013    0.360934
# 每股经营现金流_min  -0.009925    -0.044800   -0.064318    0.017024   -0.099455
# 每股经营现金流_std   0.002845     0.225500    0.235883    0.068692    0.239186
#
#               扣非每股收益_mean  扣非每股收益_max  扣非每股收益_min  扣非每股收益_std  每股净资产_mean  \
# 评分               0.038397    0.020195    0.058769   -0.010169    0.022814
# 基本每股收益_mean      0.981994    0.910090    0.594699    0.649912    0.772025
# 基本每股收益_max       0.913376    0.965170    0.394508    0.825902    0.747937
# 基本每股收益_min       0.590140    0.381743    0.984975   -0.164024    0.375918
# 基本每股收益_std       0.648016    0.815467   -0.127749    0.985854    0.603717
# 扣非每股收益_mean      1.000000    0.931616    0.599865    0.650518    0.763656
# 扣非每股收益_max       0.931616    1.000000    0.383919    0.836658    0.737406
# 扣非每股收益_min       0.599865    0.383919    1.000000   -0.167302    0.374388
# 扣非每股收益_std       0.650518    0.836658   -0.167302    1.000000    0.585231
# 每股净资产_mean       0.763656    0.737406    0.374388    0.585231    1.000000
# 每股净资产_max        0.766307    0.778488    0.330838    0.648122    0.951572
# 每股净资产_min        0.675390    0.611580    0.423349    0.428532    0.931923
# 每股净资产_std        0.485484    0.579347    0.057780    0.571958    0.516834
# 每股公积金_mean       0.244389    0.276504    0.029982    0.280616    0.659468
# 每股公积金_max        0.286899    0.344528    0.057043    0.326488    0.612031
# 每股公积金_min        0.088840    0.105140   -0.045433    0.144584    0.508129
# 每股公积金_std        0.299345    0.356536    0.107321    0.304050    0.390607
# 每股未分配利润_mean     0.843204    0.781707    0.490878    0.565444    0.845344
# 每股未分配利润_max      0.858695    0.836950    0.416617    0.664981    0.840526
# 每股未分配利润_min      0.752836    0.645848    0.585695    0.375383    0.771931
# 每股未分配利润_std      0.518056    0.643684   -0.102750    0.734857    0.468792
# 每股经营现金流_mean     0.331620    0.297465    0.168852    0.206522    0.198635
# 每股经营现金流_max      0.376509    0.381752    0.137388    0.349096    0.342252
# 每股经营现金流_min     -0.048385   -0.072907    0.019226   -0.110250   -0.124592
# 每股经营现金流_std      0.223129    0.234883    0.067292    0.235741    0.240657
#
#               ...  每股公积金_min  每股公积金_std  每股未分配利润_mean  每股未分配利润_max  \
# 评分            ...   0.030753   0.072154      0.002510     0.005038
# 基本每股收益_mean   ...   0.088699   0.306551      0.845655     0.860864
# 基本每股收益_max    ...   0.103579   0.371164      0.785180     0.842194
# 基本每股收益_min    ...  -0.042472   0.102115      0.491855     0.412755
# 基本每股收益_std    ...   0.141394   0.326207      0.581966     0.680620
# 扣非每股收益_mean   ...   0.088840   0.299345      0.843204     0.858695
# 扣非每股收益_max    ...   0.105140   0.356536      0.781707     0.836950
# 扣非每股收益_min    ...  -0.045433   0.107321      0.490878     0.416617
# 扣非每股收益_std    ...   0.144584   0.304050      0.565444     0.664981
# 每股净资产_mean    ...   0.508129   0.390607      0.845344     0.840526
# 每股净资产_max     ...   0.431885   0.577800      0.792120     0.836831
# 每股净资产_min     ...   0.561987   0.135073      0.819122     0.768699
# 每股净资产_std     ...   0.088641   0.855605      0.369161     0.499732
# 每股公积金_mean    ...   0.837848   0.520880      0.177935     0.210742
# 每股公积金_max     ...   0.639478   0.783629      0.184710     0.247182
# 每股公积金_min     ...   1.000000   0.053934      0.074596     0.079800
# 每股公积金_std     ...   0.053934   1.000000      0.175873     0.245559
# 每股未分配利润_mean  ...   0.074596   0.175873      1.000000     0.970784
# 每股未分配利润_max   ...   0.079800   0.245559      0.970784     1.000000
# 每股未分配利润_min   ...   0.053165   0.087966      0.945971     0.866936
# 每股未分配利润_std   ...   0.077468   0.348822      0.460351     0.645138
# 每股经营现金流_mean  ...  -0.072430   0.072488      0.294556     0.314115
# 每股经营现金流_max   ...   0.086844   0.083893      0.335644     0.353648
# 每股经营现金流_min   ...  -0.118790  -0.017595     -0.052530    -0.050175
# 每股经营现金流_std   ...   0.107754   0.044759      0.201413     0.207675
#
#               每股未分配利润_min  每股未分配利润_std  每股经营现金流_mean  每股经营现金流_max  \
# 评分               0.000461     0.007901     -0.023714    -0.010396
# 基本每股收益_mean      0.756312     0.523186      0.345514     0.381290
# 基本每股收益_max       0.650925     0.653390      0.319633     0.387673
# 基本每股收益_min       0.587867    -0.111698      0.166444     0.137013
# 基本每股收益_std       0.396606     0.744380      0.236677     0.360934
# 扣非每股收益_mean      0.752836     0.518056      0.331620     0.376509
# 扣非每股收益_max       0.645848     0.643684      0.297465     0.381752
# 扣非每股收益_min       0.585695    -0.102750      0.168852     0.137388
# 扣非每股收益_std       0.375383     0.734857      0.206522     0.349096
# 每股净资产_mean       0.771931     0.468792      0.198635     0.342252
# 每股净资产_max        0.680376     0.606349      0.213168     0.334513
# 每股净资产_min        0.830940     0.251756      0.154018     0.309961
# 每股净资产_std        0.187280     0.710601      0.165097     0.193110
# 每股公积金_mean       0.118473     0.229910     -0.005659     0.123711
# 每股公积金_max        0.099995     0.329539      0.018454     0.122635
# 每股公积金_min        0.053165     0.077468     -0.072430     0.086844
# 每股公积金_std        0.087966     0.348822      0.072488     0.083893
# 每股未分配利润_mean     0.945971     0.460351      0.294556     0.335644
# 每股未分配利润_max      0.866936     0.645138      0.314115     0.353648
# 每股未分配利润_min      1.000000     0.190902      0.256821     0.276274
# 每股未分配利润_std      0.190902     1.000000      0.217727     0.274857
# 每股经营现金流_mean     0.256821     0.217727      1.000000    -0.258591
# 每股经营现金流_max      0.276274     0.274857     -0.258591     1.000000
# 每股经营现金流_min     -0.037636    -0.046361      0.793866    -0.731694
# 每股经营现金流_std      0.164774     0.160628     -0.572209     0.931602
#
#               每股经营现金流_min  每股经营现金流_std
# 评分              -0.009925     0.002845
# 基本每股收益_mean     -0.044800     0.225500
# 基本每股收益_max      -0.064318     0.235883
# 基本每股收益_min       0.017024     0.068692
# 基本每股收益_std      -0.099455     0.239186
# 扣非每股收益_mean     -0.048385     0.223129
# 扣非每股收益_max      -0.072907     0.234883
# 扣非每股收益_min       0.019226     0.067292
# 扣非每股收益_std      -0.110250     0.235741
# 每股净资产_mean      -0.124592     0.240657
# 每股净资产_max       -0.109288     0.225834
# 每股净资产_min       -0.131636     0.230555
# 每股净资产_std       -0.033140     0.108728
# 每股公积金_mean      -0.101299     0.114849
# 每股公积金_max       -0.085080     0.101704
# 每股公积金_min       -0.118790     0.107754
# 每股公积金_std       -0.017595     0.044759
# 每股未分配利润_mean    -0.052530     0.201413
# 每股未分配利润_max     -0.050175     0.207675
# 每股未分配利润_min     -0.037636     0.164774
# 每股未分配利润_std     -0.046361     0.160628
# 每股经营现金流_mean     0.793866    -0.572209
# 每股经营现金流_max     -0.731694     0.931602
# 每股经营现金流_min      1.000000    -0.922333
# 每股经营现金流_std     -0.922333     1.000000
#
# [25 rows x 25 columns]
