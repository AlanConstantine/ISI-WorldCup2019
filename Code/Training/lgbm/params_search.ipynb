# %%
from IPython.display import display
import numpy as np
# import modin.pandas as pd
import pandas as pd
import datetime
import time
import gc
import matplotlib.pyplot as plt
import seaborn as sns
import lightgbm as lgb


from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import (
    LinearRegression, Ridge, Lasso, RandomizedLasso)
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import RFECV
from sklearn.feature_selection import RFE, f_regression

import itertools

import warnings
import json

warnings.filterwarnings('ignore')

plt.style.use("fivethirtyeight")
sns.set_style({'font.sans-serif': ['simsun', 'Arial']})
sns.set_style('darkgrid', {'font.sans-serif': ['simhei', 'Arial']})
# %matplotlib inline

# np.random.seed(4590)
nf_data_path = r'../../../Data/noFinacialFeatures.csv'
f_data_path = r'../../../Data//FinacialFeatures.csv'

# flevel = json.load(open(r'./feature_level.json'))

# %%
nf_df = pd.read_csv(nf_data_path)
f_df = pd.read_csv(f_data_path)

# %%
df = pd.DataFrame()
df = nf_df.copy()
f_df.drop(['企业总评分'], axis=1, inplace=True)
df = df.merge(f_df, how='left', on='企业编号')

# %%
y = df[['企业编号', '企业总评分']]
x = df.drop(['企业总评分'], axis=1)

# %%
xtrain, xtest, ytrain, ytest = train_test_split(
    x, y, test_size=0.2, random_state=31)
ytrain_id = ytrain['企业编号']
ytrain = ytrain['企业总评分']
ytest_id = ytest['企业编号']
ytest = ytest['企业总评分']
print(xtrain.shape, xtest.shape, ytrain.shape, ytest.shape)

id_train = xtrain['企业编号']
id_test = xtest['企业编号']
xtrain.drop(['企业编号'], axis=1, inplace=True)
xtest.drop(['企业编号'], axis=1, inplace=True)
# Out:
# (2364, 307) (592, 307) (2364,) (592,)

# %%
nfolds = 10
folds = KFold(n_splits=nfolds, shuffle=True, random_state=15)

# %%
def train_lgbm(xtrain, ytrain, xtest, ytest, params):
    feature_importance_df = np.zeros((xtrain.shape[1], nfolds))
    mvalid = np.zeros(len(xtrain))
    mfull = np.zeros(len(xtest))
    models = []

    for fold_, (trn_idx, val_idx) in enumerate(folds.split(xtrain.values, ytrain.values)):
        print('----')
        print("fold n°{}".format(fold_))

        x0, y0 = xtrain.iloc[trn_idx], ytrain.iloc[trn_idx]
        x1, y1 = xtrain.iloc[val_idx], ytrain.iloc[val_idx]

        trn_data = lgb.Dataset(x0, label=y0)
        val_data = lgb.Dataset(x1, label=y1)

        num_round = 10000
        clf = lgb.train(params,
                        trn_data,
                        num_round,
                        valid_sets=[trn_data, val_data],
                        verbose_eval=500,
                        early_stopping_rounds=150)

        mvalid[val_idx] = clf.predict(x1, num_iteration=clf.best_iteration)

        feature_importance_df[:, fold_] = clf.feature_importance()

        mfull += clf.predict(xtest,
                             num_iteration=clf.best_iteration) / folds.n_splits

        models.append(clf)

    test_error = np.sqrt(mean_squared_error(
        mfull.astype(int), ytest.astype(int)))
    print()
    print('rmse:', test_error)
    return models, test_error, feature_importance_df

# %%
params_all = {
    # objective and metric
    "objective": "regression",
    "metric": 'rmse',
    "boosting": "gbdt",

    # for the Leaf-wise (Best-first) Tree
    "num_leaves": 100,
    # smaller than 2^(max_depth), This is the main parameter to control the complexity of the tree model. With larger can get higher accuracy
    # Setting it to a large value can avoid growing too deep a tree, but may cause under-fitting.
    "min_data_in_leaf": 30,
    "max_depth": 7,  # limit the tree depth explicitly.

    # For Faster Speed
    "bagging_fraction": 0.7,
    "bagging_freq": 1,
    #     "max_bin": 5, # more small more faster
    "bagging_seed": 11,

    # For Better Accuracy
    "max_bin": 20,  # lager but slower
    "learning_rate": 0.005,

    # deal with over fitting
    # Use small max_bin
    # Use small num_leaves
    # Use min_data_in_leaf and min_sum_hessian_in_leaf
    # Use bagging by set bagging_fraction and bagging_freq
    # Use feature sub-sampling by set feature_fraction
    # Use bigger training data
    # Try lambda_l1, lambda_l2 and min_gain_to_split for regularization
    # Try max_depth to avoid growing deep tree
    "feature_fraction": 0.8,
    "lambda_l1": 0.9,

    "min_child_samples": 100,

    # other
    "n_estimators": 1500,
    "verbosity": -1,
    "n_jobs": -1,
}

# %%
params_range_dict = {  # for the Leaf-wise (Best-first) Tree
    "num_leaves": np.arange(10, 160, 10, dtype=int),
    # smaller than 2^(max_depth), This is the main parameter to control the complexity of the tree model. With larger can get higher accuracy
    #     "min_data_in_leaf": np.arange(10,55,5), # Setting it to a large value can avoid growing too deep a tree, but may cause under-fitting.
    # limit the tree depth explicitly.
    "max_depth": np.arange(4, 13, 1, dtype=int),

    #     # For Faster Speed
    #     "bagging_fraction": np.arange(0.5, 1,0.1),

    #     # For Better Accuracy
    "max_bin": np.arange(10, 60, 5, dtype=int),  # lager but slower

    #     "feature_fraction": np.arange(0.3, 1, 0.1),
    #     "lambda_l1": np.arange(0.01, 1, 0.05),

    #     "min_child_samples": np.arange(70, 110,10),
}

# params_range_dict ={"num_leaves": np.arange(10,30,10, dtype=int)}

# %%
def search_params(params_range_dict, xtrain, ytrain, xtest, ytest):
    best_rmse = np.inf
    count = 0
    train_dict = {}
    params_name = list(params_range_dict.keys())
    params_values = []
    for name in params_name:
        params_values.append(params_range_dict[name])

    c_params = list(itertools.product(*params_values))
    idx = [i for i in range(0, len(c_params))]

    params_df = pd.DataFrame(c_params, index=idx, columns=params_name)
    print('Iteration number:', len(params_df))
    for row in range(0, len(params_df)):
        print('*********************************Iteration: %s****************************************************' % str(count))
        starttime = time.time()
        each_params = params_df.iloc[row].to_dict()
        print('Current params:', each_params)
        params_all.update(each_params)
        models, test_error, feature_importance_df = train_lgbm(
            xtrain, ytrain, xtest, ytest, params_all)

        print("Used %s seconds" % (time.time() - starttime))

        count += 1

        if test_error < best_rmse:
            best_rmse = test_error
            train_dict = {'models': models, 'rmse': test_error,
                          'feature_importance': feature_importance_df, 'params': each_params}
        print('Current best:', best_rmse, 'Params:', train_dict['params'])
        print()

    return train_dict

# %%
train_dict = search_params(params_range_dict, xtrain, ytrain, xtest, ytest)
train_dict
# Out:
# Iteration number: 1350
# *********************************Iteration: 0****************************************************
# Current params: {'num_leaves': 10, 'max_depth': 4, 'max_bin': 10}
# ----
# fold n°0
# Training until validation scores don't improve for 150 rounds.
# [500]	training's rmse: 2.95334	valid_1's rmse: 3.62696
# [1000]	training's rmse: 2.62557	valid_1's rmse: 3.53733
# [1500]	training's rmse: 2.41282	valid_1's rmse: 3.51127
# Did not meet early stopping. Best iteration is:
# [1500]	training's rmse: 2.41282	valid_1's rmse: 3.51127
# ----
# fold n°1
# Training until validation scores don't improve for 150 rounds.
# [500]	training's rmse: 3.01238	valid_1's rmse: 2.98539
# [1000]	training's rmse: 2.67513	valid_1's rmse: 2.88633
# Early stopping, best iteration is:
# [1293]	training's rmse: 2.53672	valid_1's rmse: 2.87914
# ----
# fold n°2
# Training until validation scores don't improve for 150 rounds.
# [500]	training's rmse: 2.98382	valid_1's rmse: 3.33365
# [1000]	training's rmse: 2.64734	valid_1's rmse: 3.26794
# Early stopping, best iteration is:
# [1255]	training's rmse: 2.53223	valid_1's rmse: 3.25851
# ----
# fold n°3
# Training until validation scores don't improve for 150 rounds.
# [500]	training's rmse: 2.9892	valid_1's rmse: 3.18519
# [1000]	training's rmse: 2.6544	valid_1's rmse: 3.0999
# Early stopping, best iteration is:
# [1013]	training's rmse: 2.64815	valid_1's rmse: 3.09852
# ----
# fold n°4
# Training until validation scores don't improve for 150 rounds.
# [500]	training's rmse: 3.02289	valid_1's rmse: 2.95404
# [1000]	training's rmse: 2.68089	valid_1's rmse: 2.80388
# Early stopping, best iteration is:
# [1279]	training's rmse: 2.55438	valid_1's rmse: 2.79995
# ----
# fold n°5
# Training until validation scores don't improve for 150 rounds.
# [500]	training's rmse: 2.99721	valid_1's rmse: 3.1334
# [1000]	training's rmse: 2.65803	valid_1's rmse: 3.02295
# Early stopping, best iteration is:
# [1223]	training's rmse: 2.55348	valid_1's rmse: 3.01869
# ----
# fold n°6
# Training until validation scores don't improve for 150 rounds.
# [500]	training's rmse: 2.98095	valid_1's rmse: 3.33206
# [1000]	training's rmse: 2.65233	valid_1's rmse: 3.15883
# [1500]	training's rmse: 2.43586	valid_1's rmse: 3.14384
# Did not meet early stopping. Best iteration is:
# [1500]	training's rmse: 2.43586	valid_1's rmse: 3.14384
# ----
# fold n°7
# Training until validation scores don't improve for 150 rounds.
# [500]	training's rmse: 2.96995	valid_1's rmse: 3.42459
# [1000]	training's rmse: 2.63172	valid_1's rmse: 3.28354
# Early stopping, best iteration is:
# [1190]	training's rmse: 2.54148	valid_1's rmse: 3.27495
# ----
# fold n°8
# Training until validation scores don't improve for 150 rounds.
# [500]	training's rmse: 2.99545	valid_1's rmse: 3.13835
# [1000]	training's rmse: 2.65443	valid_1's rmse: 3.05287
# Early stopping, best iteration is:
# [1092]	training's rmse: 2.61007	valid_1's rmse: 3.04719
# ----
# fold n°9
# Training until validation scores don't improve for 150 rounds.
# [500]	training's rmse: 2.99263	valid_1's rmse: 3.27095
# [1000]	training's rmse: 2.65147	valid_1's rmse: 3.17889
# [1500]	training's rmse: 2.43458	valid_1's rmse: 3.17239
# Did not meet early stopping. Best iteration is:
# [1500]	training's rmse: 2.43458	valid_1's rmse: 3.17239
#
# rmse: 3.127093893092469
# Used 42.3843309879303 seconds
# Current best: 3.127093893092469 Params: {'num_leaves': 10, 'max_depth': 4, 'max_bin': 10}
#
# *********************************Iteration: 1****************************************************
# Current params: {'num_leaves': 10, 'max_depth': 4, 'max_bin': 15}
# ----
# fold n°0
# Training until validation scores don't improve for 150 rounds.
# [500]	training's rmse: 2.93828	valid_1's rmse: 3.61955
# [1000]	training's rmse: 2.6037	valid_1's rmse: 3.53855
# [1500]	training's rmse: 2.38737	valid_1's rmse: 3.51562
# Did not meet early stopping. Best iteration is:
# [1500]	training's rmse: 2.38737	valid_1's rmse: 3.51562
# ----
# fold n°1
# Training until validation scores don't improve for 150 rounds.
# [500]	training's rmse: 2.99877	valid_1's rmse: 3.00896
# Early stopping, best iteration is:
# [834]	training's rmse: 2.74245	valid_1's rmse: 2.93192
# ----
# fold n°2
# Training until validation scores don't improve for 150 rounds.
# [500]	training's rmse: 2.9638	valid_1's rmse: 3.35229
# [1000]	training's rmse: 2.62074	valid_1's rmse: 3.28987
# Early stopping, best iteration is:
# [918]	training's rmse: 2.66219	valid_1's rmse: 3.28712
# ----
# fold n°3
# Training until validation scores don't improve for 150 rounds.
# [500]	training's rmse: 2.98071	valid_1's rmse: 3.20052
# [1000]	training's rmse: 2.63764	valid_1's rmse: 3.10972
# Early stopping, best iteration is:
# [1003]	training's rmse: 2.63622	valid_1's rmse: 3.10943
# ----
# fold n°4
# Training until validation scores don't improve for 150 rounds.
# [500]	training's rmse: 3.00812	valid_1's rmse: 2.9164
# [1000]	training's rmse: 2.65804	valid_1's rmse: 2.76282
# Early stopping, best iteration is:
# [1103]	training's rmse: 2.60609	valid_1's rmse: 2.75631
# ----
# fold n°5
# Training until validation scores don't improve for 150 rounds.
# [500]	training's rmse: 2.97506	valid_1's rmse: 3.16601
# [1000]	training's rmse: 2.62996	valid_1's rmse: 3.05889
# Early stopping, best iteration is:
# [1073]	training's rmse: 2.59315	valid_1's rmse: 3.05452
# ----
# fold n°6
# Training until validation scores don't improve for 150 rounds.
# [500]	training's rmse: 2.9742	valid_1's rmse: 3.31392
# [1000]	training's rmse: 2.63756	valid_1's rmse: 3.15041
# Early stopping, best iteration is:
# [1328]	training's rmse: 2.48652	valid_1's rmse: 3.13199
# ----
# fold n°7
# Training until validation scores don't improve for 150 rounds.
# [500]	training's rmse: 2.9508	valid_1's rmse: 3.46026
# [1000]	training's rmse: 2.60981	valid_1's rmse: 3.32139
# Early stopping, best iteration is:
# [1140]	training's rmse: 2.54262	valid_1's rmse: 3.31138
# ----
# fold n°8
# Training until validation scores don't improve for 150 rounds.
# [500]	training's rmse: 2.97912	valid_1's rmse: 3.14913
# [1000]	training's rmse: 2.63565	valid_1's rmse: 3.06967
# Early stopping, best iteration is:
# [1175]	training's rmse: 2.55207	valid_1's rmse: 3.06489
# ----
# fold n°9
# Training until validation scores don't improve for 150 rounds.
# [500]	training's rmse: 2.97664	valid_1's rmse: 3.2702
# [1000]	training's rmse: 2.62839	valid_1's rmse: 3.17985
# Early stopping, best iteration is:
# [1275]	training's rmse: 2.49875	valid_1's rmse: 3.17167
#
# rmse: 3.1241214981391385
# Used 26.932353496551514 seconds
# Current best: 3.1241214981391385 Params: {'num_leaves': 10, 'max_depth': 4, 'max_bin': 15}
#
# *********************************Iteration: 2****************************************************
# Current params: {'num_leaves': 10, 'max_depth': 4, 'max_bin': 20}
# ----
# fold n°0
# Training until validation scores don't improve for 150 rounds.
# [500]	training's rmse: 2.92859	valid_1's rmse: 3.61063
# [1000]	training's rmse: 2.58939	valid_1's rmse: 3.52182
# [1500]	training's rmse: 2.37489	valid_1's rmse: 3.49044
# Did not meet early stopping. Best iteration is:
# [1500]	training's rmse: 2.37489	valid_1's rmse: 3.49044
# ----
# fold n°1
# Training until validation scores don't improve for 150 rounds.
# [500]	training's rmse: 2.9805	valid_1's rmse: 3.01432
# [1000]	training's rmse: 2.62963	valid_1's rmse: 2.92121
# Early stopping, best iteration is:
# [1172]	training's rmse: 2.54423	valid_1's rmse: 2.91495
# ----
# fold n°2
# Training until validation scores don't improve for 150 rounds.
# [500]	training's rmse: 2.95493	valid_1's rmse: 3.32161
# [1000]	training's rmse: 2.61243	valid_1's rmse: 3.25463
# Early stopping, best iteration is:
# [1298]	training's rmse: 2.47671	valid_1's rmse: 3.24358
# ----
# fold n°3
# Training until validation scores don't improve for 150 rounds.
# [500]	training's rmse: 2.96802	valid_1's rmse: 3.20365
# [1000]	training's rmse: 2.62556	valid_1's rmse: 3.11466
# Early stopping, best iteration is:
# [1064]	training's rmse: 2.59482	valid_1's rmse: 3.11205
# ----
# fold n°4
# Training until validation scores don't improve for 150 rounds.
# [500]	training's rmse: 2.99498	valid_1's rmse: 2.93159
# [1000]	training's rmse: 2.64764	valid_1's rmse: 2.78846
# Early stopping, best iteration is:
# [1129]	training's rmse: 2.58371	valid_1's rmse: 2.78463
# ----
# fold n°5
# Training until validation scores don't improve for 150 rounds.
# [500]	training's rmse: 2.96941	valid_1's rmse: 3.14189
# [1000]	training's rmse: 2.62396	valid_1's rmse: 3.04137
# Early stopping, best iteration is:
# [1188]	training's rmse: 2.53514	valid_1's rmse: 3.03545
# ----
# fold n°6
# Training until validation scores don't improve for 150 rounds.
# [500]	training's rmse: 2.96068	valid_1's rmse: 3.32344
# [1000]	training's rmse: 2.62003	valid_1's rmse: 3.17666
# [1500]	training's rmse: 2.39609	valid_1's rmse: 3.15827
# Did not meet early stopping. Best iteration is:
# [1500]	training's rmse: 2.39609	valid_1's rmse: 3.15827
# ----
# fold n°7
# Training until validation scores don't improve for 150 rounds.
# [500]	training's rmse: 2.94637	valid_1's rmse: 3.42669
# [1000]	training's rmse: 2.60136	valid_1's rmse: 3.29838
# Early stopping, best iteration is:
# [1239]	training's rmse: 2.48692	valid_1's rmse: 3.28793
# ----
# fold n°8
# Training until validation scores don't improve for 150 rounds.
# [500]	training's rmse: 2.95951	valid_1's rmse: 3.13541
# [1000]	training's rmse: 2.61093	valid_1's rmse: 3.05667
# Early stopping, best iteration is:
# [1037]	training's rmse: 2.59285	valid_1's rmse: 3.05343
# ----
# fold n°9
# Training until validation scores don't improve for 150 rounds.
# [500]	training's rmse: 2.9639	valid_1's rmse: 3.26821
# [1000]	training's rmse: 2.61821	valid_1's rmse: 3.18008
# [1500]	training's rmse: 2.39629	valid_1's rmse: 3.1765
# Did not meet early stopping. Best iteration is:
# [1500]	training's rmse: 2.39629	valid_1's rmse: 3.1765
#
# rmse: 3.107586619001085
# Used 31.520885705947876 seconds
# Current best: 3.107586619001085 Params: {'num_leaves': 10, 'max_depth': 4, 'max_bin': 20}
#
# *********************************Iteration: 3****************************************************
# Current params: {'num_leaves': 10, 'max_depth': 4, 'max_bin': 25}
# ----
# fold n°0
# Training until validation scores don't improve for 150 rounds.
# [500]	training's rmse: 2.91941	valid_1's rmse: 3.60423
# [1000]	training's rmse: 2.58141	valid_1's rmse: 3.5194
# [1500]	training's rmse: 2.37119	valid_1's rmse: 3.49574
# Did not meet early stopping. Best iteration is:
# [1500]	training's rmse: 2.37119	valid_1's rmse: 3.49574
# ----
# fold n°1
# Training until validation scores don't improve for 150 rounds.
