# %%
from pprint import pprint
import pandas as pd
import os

# %%
datapath = r'../../Data/CompInfo'

file_attributes={}
# df_list = {}
for root, dirs, files in os.walk(datapath):
    for file in files:
        filepath = root+'/'+file
#         fileid=int(file.split('_')[0])
        df = pd.read_excel(filepath)
        file_attributes[file.replace('.xlsx','')] = list(df.columns.values)
#         file_attributes[fileid]['df'] = df
        print(file, 'done')
# Out:
# 商标.xlsx done
# 上市信息财务信息-财务风险指标.xlsx done
# 软著著作权.xlsx done
# 上市信息财务信息资产负债表.xlsx done
# 竞品.xlsx done
# 工商基本信息表.xlsx done
# 纳税A级年份.xlsx done
# 专利.xlsx done
# 年报-社保信息.xlsx done
# 上市公司财务信息-每股指标.xlsx done
# 招投标.xlsx done
# 年报-的对外提供保证担保信息.xlsx done
# 购地-结果公告.xlsx done
# 海关进出口信用.xlsx done
# 产品.xlsx done
# 企业评分.xlsx done
# 上市信息财务信息盈利能力指标.xlsx done
# 一般纳税人.xlsx done
# 购地-市场交易-土地抵押.xlsx done
# 年报-企业基本信息.xlsx done
# 购地-市场交易-土地转让.xlsx done
# 年报-股东（发起人）及出资信息.xlsx done
# 购地-地块公示.xlsx done
# 年报-对外投资信息.xlsx done
# 资质认证.xlsx done
# 债券信息.xlsx done
# 作品著作权.xlsx done
# 上市信息财务信息-利润表.xlsx done
# 融资信息.xlsx done
# 年报-网站或网点信息.xlsx done
# 项目信息.xlsx done
# 年报-企业资产状况信息.xlsx done
# 购地-房地产大企业购地情况.xlsx done
# 购地-房地产大地块出让情况.xlsx done
# 上市信息财务信息-成长能力指标.xlsx done
# 年报-股东股权转让.xlsx done
# 上市信息财务信息运营能力指标.xlsx done
# 上市信息财务信息-现金流量表.xlsx done

# %%
file_attributes
# Out:
# {'商标': ['企业编号', '商标状态', '申请日期', '专用权期限开始日期', '专用权期限结束日期', '商标使用期限时间段'],
#  '上市信息财务信息-财务风险指标': ['企业编号',
#   '标题',
#   '日期',
#   '资产负债率(%)',
#   '流动负债/总负债(%)',
#   '流动比率',
#   '速动比率'],
#  '软著著作权': ['企业编号', '软件全称', '软件著作权版本号', '软件著作权登记批准日期'],
#  '上市信息财务信息资产负债表': ['企业编号',
#   '标题',
#   '日期',
#   '资产:货币资金(元)',
#   '资产:应收账款(元)',
#   '资产:其它应收款(元)',
#   '资产:存货(元)',
#   '资产:流动资产合计(元)',
#   '资产:长期股权投资(元)',
#   '资产:累计折旧(元)',
#   '资产:固定资产(元)',
#   '资产:无形资产(元)',
#   '资产:资产总计(元)',
#   '负债:应付账款(元)',
#   '负债:预收账款(元)',
#   '负债:存货跌价准备(元)',
#   '负债:流动负债合计(元)',
#   '负债:长期负债合计(元)',
#   '负债:负债合计(元)',
#   '权益:实收资本(或股本)(元)',
#   '权益:资本公积金(元)',
#   '权益:盈余公积金(元)',
#   '权益:股东权益合计(元)',
#   '流动比率'],
#  '竞品': ['企业编号', '竞品的行业', '竞品的标签', '竞品轮次', '竞品详细地址', '竞品运营状态', '竞品成立时间'],
#  '工商基本信息表': ['企业编号',
#   '注册资本（万元）',
#   '注册资本币种(正则)',
#   '成立日期',
#   '经营状态',
#   '行业大类（代码）',
#   '行业小类（代码）',
#   '类型',
#   '省份代码',
#   '城市代码',
#   '地区代码',
#   '是否上市',
#   '经营期限自',
#   '经营期限至',
#   '登记机关区域代码',
#   '发照日期',
#   '员工人数',
# ...

# %% [markdown]
# ```
# {'商标': ['企业编号', '商标状态', '申请日期', '专用权期限开始日期', '专用权期限结束日期', '商标使用期限时间段'],
#  '上市信息财务信息-财务风险指标': ['企业编号',
#   '标题',
#   '日期',
#   '资产负债率(%)',
#   '流动负债/总负债(%)',
#   '流动比率',
#   '速动比率'],
#  '软著著作权': ['企业编号', '软件全称', '软件著作权版本号', '软件著作权登记批准日期'],
#  '上市信息财务信息资产负债表': ['企业编号',
#   '标题',
#   '日期',
#   '资产:货币资金(元)',
#   '资产:应收账款(元)',
#   '资产:其它应收款(元)',
#   '资产:存货(元)',
#   '资产:流动资产合计(元)',
#   '资产:长期股权投资(元)',
#   '资产:累计折旧(元)',
#   '资产:固定资产(元)',
#   '资产:无形资产(元)',
#   '资产:资产总计(元)',
#   '负债:应付账款(元)',
#   '负债:预收账款(元)',
#   '负债:存货跌价准备(元)',
#   '负债:流动负债合计(元)',
#   '负债:长期负债合计(元)',
#   '负债:负债合计(元)',
#   '权益:实收资本(或股本)(元)',
#   '权益:资本公积金(元)',
#   '权益:盈余公积金(元)',
#   '权益:股东权益合计(元)',
#   '流动比率'],
#  '竞品': ['企业编号', '竞品的行业', '竞品的标签', '竞品轮次', '竞品详细地址', '竞品运营状态', '竞品成立时间'],
#  '工商基本信息表': ['企业编号',
#   '注册资本（万元）',
#   '注册资本币种(正则)',
#   '成立日期',
#   '经营状态',
#   '行业大类（代码）',
#   '行业小类（代码）',
#   '类型',
#   '省份代码',
#   '城市代码',
#   '地区代码',
#   '是否上市',
#   '经营期限自',
#   '经营期限至',
#   '登记机关区域代码',
#   '发照日期',
#   '员工人数',
#   '注销原因',
#   '注销时间'],
#  '纳税A级年份': ['企业编号', '纳税A级年份'],
#  '专利': ['企业编号', '专利类型', '授权公告日', '申请日'],
#  '年报-社保信息': ['企业编号',
#   '城镇职工基本养老保险人数',
#   '失业保险人数',
#   '职工基本医疗保险人数',
#   '工伤保险人数',
#   '生育保险人数',
#   '单位参加城镇职工基本养老保险缴费基数',
#   '单位参加失业保险缴费基数',
#   '单位参加职工基本医疗保险缴费基数',
#   '单位参加工伤保险缴费基数',
#   '单位参加生育保险缴费基数',
#   '参加城镇职工基本养老保险本期实际缴费金额',
#   '参加失业保险本期实际缴费金额',
#   '参加职工基本医疗保险本期实际缴费金额',
#   '参加工伤保险本期实际缴费金额',
#   '参加生育保险本期实际缴费金额',
#   '单位参加城镇职工基本养老保险累计欠缴金额',
#   '单位参加失业保险累计欠缴金额',
#   '单位参加职工基本医疗保险累计欠缴金额',
#   '单位参加工伤保险累计欠缴金额',
#   '单位参加生育保险累计欠缴金额',
#   '年报年份'],
#  '上市公司财务信息-每股指标': ['企业编号',
#   '标题',
#   '日期',
#   '基本每股收益(元)',
#   '扣非每股收益(元)',
#   '稀释每股收益(元)',
#   '每股净资产(元)',
#   '每股公积金(元)',
#   '每股未分配利润(元)',
#   '每股经营现金流(元)'],
#  '招投标': ['企业编号', '公告类型', '中标或招标', '省份', '发布时间'],
#  '年报-的对外提供保证担保信息': ['企业编号',
#   '主债权数额',
#   '保证担保的范围',
#   '保证的期间',
#   '保证的方式',
#   '主债权种类',
#   '履行债务的期限',
#   '年报年份'],
#  '购地-结果公告': ['企业编号',
#   '总面积',
#   '土地用途',
#   '供应方式',
#   '签订日期',
#   '土地来源',
#   '土地使用年限',
#   '行业分类',
#   '土地级别',
#   '成交价格（万元）',
#   '约定容积率上限',
#   '约定容积率下限',
#   '约定交地时间',
#   '约定开工时间',
#   '约定竣工时间',
#   '实际开工时间',
#   '实际竣工时间',
#   '批准单位'],
#  '海关进出口信用': ['企业编号', '经济区划', '经营类别', '海关注销标志', '年报情况', '信用等级'],
#  '产品': ['企业编号', '产品类型'],
#  '企业评分': ['企业编号', '企业总评分'],
#  '上市信息财务信息盈利能力指标': ['企业编号',
#   '标题',
#   '日期',
#   '加权净资产收益率(%)',
#   '摊薄净资产收益率(%)',
#   '摊薄总资产收益率(%)',
#   '毛利率(%)',
#   '净利率(%)',
#   '实际税率(%)'],
#  '一般纳税人': ['企业编号',
#   '纳税人资格',
#   '认定日期',
#   '有效日期期起',
#   '有效截止日期',
#   '是否具有一般纳税人资格',
#   '纳税人状态',
#   '登记注册类型',
#   '扣缴义务',
#   '出口状态备案状态',
#   '是否按季申报'],
#  '购地-市场交易-土地抵押': ['企业编号',
#   '土地抵押人性质',
#   '抵押面积(公顷)',
#   '土地用途',
#   '抵押土地用途',
#   '抵押土地权属性质与使用权类型',
#   '土地面积',
#   '评估金额(万元)',
#   '抵押金额(万元)',
#   '土地抵押登记起始时间',
#   '土地抵押登记结束时间'],
#  '年报-企业基本信息': ['企业编号',
#   '注册资本',
#   '企业经营状态',
#   '从业人数',
#   '是否有网站或网点',
#   '企业是否有投资信息或购买其他公司股权',
#   '有限责任公司本年度是否发生股东股权转',
#   '是否提供对外担保',
#   '发布日期',
#   '年报年份'],
#  '购地-市场交易-土地转让': ['企业编号',
#   '成交时间',
#   '土地面积(公顷)',
#   '土地用途',
#   '土地使用年限',
#   '土地级别',
#   '土地使用权类型',
#   '土地利用状况',
#   '转让方式',
#   '转让价格(万元)'],
#  '年报-股东（发起人）及出资信息': ['企业编号', '股东类型', '股东所占比例', '认缴出资信息', '实缴出资信息', '年报年份'],
#  '购地-地块公示': ['企业编号',
#   '行政区',
#   '时间',
#   '公示日期',
#   '土地用途',
#   '土地面积（公顷）',
#   '出让年限',
#   '成交价（万元）',
#   '土地使用条件'],
#  '年报-对外投资信息': ['企业编号', '投资金额', '投资占比', '年报年份'],
#  '资质认证': ['企业编号', '证书名称', '有效期起止日期', '有效期截至日期', '状态'],
#  '债券信息': ['企业编号',
#   '债券信用评级',
#   '债券期限',
#   '债券品种',
#   '发行日期',
#   '付息日期',
#   '兑付日期',
#   '计划发行总额（亿元）',
#   '实际发行总额（亿元）',
#   '币种',
#   '流通场所',
#   '票面利率（%）',
#   '主体信用评级',
#   '付息方式'],
#  '作品著作权': ['企业编号', '作品著作权类别', '作品著作权登记日期', '作品著作权创作完成日期', '作品著作权首次发布日期'],
#  '上市信息财务信息-利润表': ['企业编号',
#   '标题',
#   '日期',
#   '营业收入(元)',
#   '营业成本(元)',
#   '销售费用(元)',
#   '财务费用(元)',
#   '管理费用(元)',
#   '资产减值损失(元)',
#   '投资收益(元)',
#   '营业利润(元)',
#   '利润总额(元)',
#   '所得税(元)',
#   '归属母公司所有者净利润(元)'],
#  '融资信息': ['企业编号', '融资日期', '轮次', '投资金额'],
#  '年报-网站或网点信息': ['企业编号', '年报年份'],
#  '项目信息': ['企业编号', '行业', '标签', '企业规模', '运营状态', '简介', '项目成立时间'],
#  '年报-企业资产状况信息': ['企业编号',
#   '资产总额',
#   '所有者权益合计',
#   '营业总收入',
#   '利润总额',
#   '主营业务收入',
#   '主营业务',
#   '净利润',
#   '纳税总额',
#   '负债总额',
#   '实际员工数量',
#   '年报年份'],
#  '购地-房地产大企业购地情况': ['企业编号',
#   '行政区',
#   '签订日期',
#   '供地总面积（公顷）',
#   '约定动工时间',
#   '土地用途',
#   '供应方式',
#   '最小容积率',
#   '最大容积率',
#   '成交价款（万元）',
#   '约定竣工时间'],
#  '购地-房地产大地块出让情况': ['企业编号',
#   '签订日期',
#   '供地总面积',
#   '约定动工时间',
#   '土地用途',
#   '供应方式',
#   '容积率下限',
#   '容积率上限',
#   '成交价款（万元）',
#   '约定竣工时间'],
#  '上市信息财务信息-成长能力指标': ['企业编号',
#   '标题',
#   '日期',
#   '营业总收入(元)',
#   '毛利润(元)',
#   '归属净利润(元)',
#   '扣非净利润(元)',
#   '营业总收入同比增长(元)',
#   '归属净利润同比增长(元)',
#   '扣非净利润同比增长(元)',
#   '营业总收入滚动环比增长(元)',
#   '归属净利润滚动环比增长(元)',
#   '扣非净利润滚动环比增长(元)'],
#  '年报-股东股权转让': ['企业编号', '变更前股权比例', '变更后股权比例', '股权变更日期', '年报年份'],
#  '上市信息财务信息运营能力指标': ['企业编号',
#   '标题',
#   '日期',
#   '总资产周转率(次)',
#   '应收账款周转天数(天)',
#   '存货周转天数(天)'],
#  '上市信息财务信息-现金流量表': ['企业编号',
#   '标题',
#   '日期',
#   '经营:销售商品、提供劳务收到的现金(元)',
#   '经营:收到的税费返还(元)',
#   '经营:收到其他与经营活动有关的现金(元)',
#   '经营:经营活动现金流入小计(元)',
#   '经营:购买商品、接受劳务支付的现金(元)',
#   '经营:支付给职工以及为职工支付的现金(元)',
#   '经营:支付的各项税费(元)',
#   '经营:支付其他与经营活动有关的现金(元)',
#   '经营:经营活动现金流出小计(元)',
#   '经营:经营活动产生的现金流量净额(元)',
#   '投资:取得投资收益所收到的现金(元)',
#   '投资:处置固定资产、无形资产和其他长期资产收回的现金净额(元)',
#   '投资:投资活动现金流入小计(元)',
#   '投资:购建固定资产、无形资产和其他长期资产支付的现金(元)',
#   '投资:投资支付的现金(元)',
#   '投资:投资活动现金流出小计(元)',
#   '投资:投资活动产生的现金流量净额(元)',
#   '筹资:吸收投资收到的现金(元)',
#   '筹资:取得借款收到的现金(元)',
#   '筹资:筹资活动现金流入小计(元)',
#   '筹资:偿还债务支付的现金(元)',
#   '筹资:分配股利、利润或偿付利息支付的现金(元)',
#   '筹资:筹资活动现金流出小计(元)',
#   '筹资活动产生的现金流量净额(元)']
# }
# ```
