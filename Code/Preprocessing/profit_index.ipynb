# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel(r'../../Data/CompInfo/上市信息财务信息盈利能力指标.xlsx')

# %%
df.info()
df.head(n=5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28887 entries, 0 to 28886
# Data columns (total 9 columns):
# 企业编号           28887 non-null int64
# 标题             28887 non-null object
# 日期             28887 non-null object
# 加权净资产收益率(%)    28887 non-null object
# 摊薄净资产收益率(%)    28887 non-null object
# 摊薄总资产收益率(%)    28887 non-null object
# 毛利率(%)         28203 non-null object
# 净利率(%)         28887 non-null object
# 实际税率(%)        28887 non-null object
# dtypes: int64(1), object(8)
# memory usage: 2.0+ MB
#    企业编号      标题          日期 加权净资产收益率(%) 摊薄净资产收益率(%) 摊薄总资产收益率(%) 毛利率(%)  \
# 0  1001  盈利能力指标  2018-09-30      10.48%       9.49%       0.71%    NaN
# 1  1001  盈利能力指标  2018-06-30       6.97%       6.48%       0.47%    NaN
# 2  1001  盈利能力指标  2018-03-31       3.45%       3.34%       0.24%    NaN
# 3  1001  盈利能力指标  2017-12-31      14.45%      12.75%       0.92%    NaN
# 4  1001  盈利能力指标  2017-09-30      11.51%      10.04%       0.71%    NaN
#
#    净利率(%) 实际税率(%)
# ...

# %%
df.convert_objects(convert_numeric=True)
# Out:
# /home/alan/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use DataFrame.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   """Entry point for launching an IPython kernel.
#        企业编号      标题          日期 加权净资产收益率(%) 摊薄净资产收益率(%) 摊薄总资产收益率(%)  毛利率(%)  \
# 0      1001  盈利能力指标  2018-09-30      10.48%       9.49%       0.71%     --%
# 1      1001  盈利能力指标  2018-06-30       6.97%       6.48%       0.47%     --%
# 2      1001  盈利能力指标  2018-03-31       3.45%       3.34%       0.24%     --%
# 3      1001  盈利能力指标  2017-12-31      14.45%      12.75%       0.92%     --%
# 4      1001  盈利能力指标  2017-09-30      11.51%      10.04%       0.71%     --%
# 5      1001  盈利能力指标  2017-06-30       7.85%       7.28%       0.48%     --%
# 6      1001  盈利能力指标  2017-03-31       3.96%       3.81%       0.25%     --%
# ...

# %%
df['毛利率(%)'] = df['毛利率(%)'].replace('--%', np.nan)

# %%
df.info()
df.head(n=5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28887 entries, 0 to 28886
# Data columns (total 9 columns):
# 企业编号           28887 non-null int64
# 标题             28887 non-null object
# 日期             28887 non-null object
# 加权净资产收益率(%)    28887 non-null object
# 摊薄净资产收益率(%)    28887 non-null object
# 摊薄总资产收益率(%)    28887 non-null object
# 毛利率(%)         28203 non-null object
# 净利率(%)         28887 non-null object
# 实际税率(%)        28887 non-null object
# dtypes: int64(1), object(8)
# memory usage: 2.0+ MB
#    企业编号      标题          日期 加权净资产收益率(%) 摊薄净资产收益率(%) 摊薄总资产收益率(%) 毛利率(%)  \
# 0  1001  盈利能力指标  2018-09-30      10.48%       9.49%       0.71%    NaN
# 1  1001  盈利能力指标  2018-06-30       6.97%       6.48%       0.47%    NaN
# 2  1001  盈利能力指标  2018-03-31       3.45%       3.34%       0.24%    NaN
# 3  1001  盈利能力指标  2017-12-31      14.45%      12.75%       0.92%    NaN
# 4  1001  盈利能力指标  2017-09-30      11.51%      10.04%       0.71%    NaN
#
#    净利率(%) 实际税率(%)
# ...

# %%
a = 'abcd'
a.split('b')
# Out:
# ['a', 'cd']

# %%
df['毛利率(%)'].str.strip('%').astype('float') / 100.0
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9        0.2856
# 10       0.3215
# 11       0.3971
# 12       0.4056
# 13       0.3895
# 14       0.3946
# 15       0.3868
# 16       0.3961
# 17       0.3936
# 18       0.1137
# 19       0.1240
# 20       0.1472
# 21       0.1070
# 22       0.1099
# 23       0.1107
# 24       0.1156
# 25       0.1400
# 26       0.1500
# 27       0.5313
# 28       0.5307
# 29       0.5206
#           ...
# 28857    0.4203
# 28858    0.4077
# 28859    0.4437
# 28860    0.2703
# 28861    0.3182
# 28862    0.3770
# 28863    0.3507
# 28864    0.3720
# 28865    0.3829
# 28866    0.3626
# 28867    0.4128
# 28868    0.4018
# 28869    0.3302
# 28870    0.3866
# 28871    0.4268
# 28872    0.4458
# 28873    0.4631
# 28874    0.4803
# 28875    0.4528
# 28876    0.4538
# 28877    0.4688
# 28878    0.2139
# 28879    0.2194
# 28880    0.2190
# ...
